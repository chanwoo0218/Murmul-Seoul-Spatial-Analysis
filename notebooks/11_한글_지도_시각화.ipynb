# %% [markdown]
# # 한글 지도 시각화
# 한글 레이블과 범례가 깨지지 않도록 폰트·지도 출력을 정리한 시각화 노트북입니다.

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = ['AppleGothic','Malgun Gothic','DejaVu Sans']
plt.rcParams['axes.unicode_minus'] = False
# gdf = gpd.read_file('../outputs/block_potential_sales.geojson')
# ax = gdf.plot(column='potential_sales', cmap='viridis', legend=True, figsize=(10,10))
# ax.set_title('블록별 잠재매출')
# ax.set_axis_off(); plt.tight_layout(); plt.show()
