# %% [markdown]
# # 블록별 지표 계산
# 보행·버스·지하철·도로 접근성, POI 밀도, 건물 용량을 블록 단위로 계산합니다.

# %%
import pandas as pd
import numpy as np
def minmax(s):
    s = pd.to_numeric(s, errors='coerce').fillna(0)
    return (s-s.min())/(s.max()-s.min()) if s.max()!=s.min() else s*0
# blocks = pd.read_csv('../outputs/block_indicators.csv')
# indicator_cols = ['walk_access','bus_access','subway_access','road_access','poi_density','building_capacity']
# for col in indicator_cols:
#     blocks[col + '_scaled'] = minmax(blocks[col])
# blocks.to_csv('../outputs/block_indicators_scaled.csv', index=False)
