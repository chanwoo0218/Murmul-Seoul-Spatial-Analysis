# %% [markdown]
# # 블록 폴리곤 통합
# 분할된 블록 공간자료를 통합하고 geometry 유효성을 점검하는 분석 흐름입니다.

# %%
from pathlib import Path
import geopandas as gpd
import pandas as pd
files = sorted(Path('../data/external/blocks').glob('*.geojson'))
# blocks = pd.concat([gpd.read_file(p).to_crs(5179) for p in files], ignore_index=True)
# blocks = gpd.GeoDataFrame(blocks, geometry='geometry', crs=5179)
# blocks['geometry'] = blocks.geometry.buffer(0)
# blocks.to_file('../outputs/blocks_merged.geojson', driver='GeoJSON')
