# %% [markdown]
# # 역별 동적 시각화
# 역별 지표와 시간 변화를 Plotly 애니메이션으로 표현합니다.

# %%
import pandas as pd
import plotly.express as px
# df = pd.read_csv('../data/external/station_time_series.csv')
# fig = px.scatter_map(df, lat='위도', lon='경도', size='승하차', color='전년대비', animation_frame='월', hover_name='역명', zoom=10)
# fig.show()
