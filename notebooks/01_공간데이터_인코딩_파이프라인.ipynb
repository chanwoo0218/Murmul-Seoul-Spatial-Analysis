# %% [markdown]
# # 공간데이터 인코딩 파이프라인
# ZIP의 원본 공간자료 통합 흐름을 저장소 상대경로 기준으로 정리했습니다.

# %%
from pathlib import Path
import pandas as pd
import geopandas as gpd
DATA = Path('../data/external')
OUT = Path('../outputs')
OUT.mkdir(exist_ok=True)

# %%
# CSV는 파일별 인코딩을 확인해 읽고, 공간자료는 EPSG:5179로 통일합니다.
# table = pd.read_csv(DATA / 'table.csv', encoding='cp949')
# space = gpd.read_file(DATA / 'space.geojson').to_crs(5179)
# space.to_file(OUT / 'space_5179.geojson', driver='GeoJSON')
