# %% [markdown]
# # 시간대별 매출 시각화
# 시간대별 승하차·매출 패턴을 비교하는 원본 시각화 흐름입니다.

# %%
import pandas as pd
import plotly.express as px
# df = pd.read_csv('../data/external/hourly_sales.csv')
# fig = px.line(df, x='시간대', y='매출', color='역명', markers=True)
# fig.show()
