# %% [markdown]
# # 정적·동적 통합 시각화
# 블록 잠재매출 정적 지도와 시간대별 동적 차트를 함께 구성합니다.

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
# blocks = gpd.read_file('../outputs/block_potential_sales.geojson')
# blocks.plot(column='potential_sales', legend=True, figsize=(10,10))
# plt.show()
# hourly = pd.read_csv('../data/external/hourly_sales.csv')
# px.line(hourly, x='시간대', y='매출', color='역명').show()
