# %% [markdown]
# # 교차매핑 및 잠재매출 검증 A
# 2020년 잠재매출과 2021~2022년 관측매출을 연결해 순위·오차 지표를 검증합니다.

# %%
import pandas as pd
import numpy as np
from scipy.stats import spearmanr, kendalltau
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# df = pd.read_csv('../outputs/validation_2020_2022.csv').dropna()
# y_true = df['actual_sales_2022']
# y_pred = df['potential_sales_2020']
# print('MAE', mean_absolute_error(y_true,y_pred))
# print('RMSE', np.sqrt(mean_squared_error(y_true,y_pred)))
# print('R2', r2_score(y_true,y_pred))
# print('Spearman', spearmanr(y_true,y_pred).correlation)
# print('Kendall', kendalltau(y_true,y_pred).correlation)
