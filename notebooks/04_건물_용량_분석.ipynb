# %% [markdown]
# # 건물 용량 분석
# 건축물 면적·용도 정보를 블록 단위 상업활동 수용력으로 집계하는 노트북입니다.

# %%
import geopandas as gpd
import pandas as pd
# buildings = gpd.read_file('../data/external/buildings.geojson').to_crs(5179)
# blocks = gpd.read_file('../outputs/blocks_merged.geojson').to_crs(5179)
# buildings['capacity'] = buildings.geometry.area
# joined = gpd.sjoin(buildings, blocks[['block_id','geometry']], predicate='intersects')
# capacity = joined.groupby('block_id', as_index=False)['capacity'].sum()
# capacity.to_csv('../outputs/block_building_capacity.csv', index=False)
